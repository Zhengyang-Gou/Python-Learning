# %% [markdown]
# # 3 函数

# %% [markdown]
# ## 3.1 调用函数

# %%
print(abs(-42))
print(max(10, 20, 5))
print(int(6.30))
print(float('6.30'))
print(bool(1))
print(bool(0))

# %% [markdown]
# ## 3.2 定义函数

# %%
def myabs(x):
    if not isinstance(x, (int, float)): # isinstance()函数用来判断一个对象是否是一个已知的类型，类似type()
        raise TypeError('bad operand type') # raise语句用于抛出一个指定的异常
    if x >= 0:
        return x
    else:
        return -x
print(myabs(-99))

# %% [markdown]
# 函数还能返回多个值

# %%
import math

def move(x, y, step, angle=0):
    nx = x + step * math.cos(angle)
    ny = y - step * math.sin(angle)
    return nx, ny
x, y = move(100, 100, 60, math.pi / 6) # 用变量接收多个返回值
print(x, y)
r = move(100, 100, 60, math.pi / 6) # 用一个变量接收多个返回值，实际上是一个tuple
print(r)

# %%
import math

def quadratic(a,b,c):
    if b**2 - 4*a*c < 0 and a != 0: 
        return '无实数解'
    elif a == 0:
        return '不是一元二次方程'
    else:
        x1 = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
        x2 = (-b - math.sqrt(b**2 - 4*a*c)) / (2*a)
        return x1, x2
print(quadratic(2, 3, 1))

# %% [markdown]
# ## 3.3 函数的参数

# %% [markdown]
# Python的函数定义非常简单，但灵活度却非常大。除了正常定义的必选参数外，还可以使用默认参数、可变参数和关键字参数，使得函数定义出来的接口，不但能处理复杂的参数，还可以简化调用者的代码。

# %% [markdown]
# 位置参数：

# %%
def power(x, n):
    s = 1
    while n > 0:
        n = n - 1
        s = s * x
    return s
print(power(5, 3))

# %% [markdown]
# 默认参数：当经常使用一个值时，可以设为一个默认值
#
# 必选参数在前，默认参数在后，否则Python的解释器会报错
#
# 当函数有多个参数时，把变化大的参数放前面，变化小的参数放后面
#
# 定义默认参数必须指向不变对象

# %%
def power(x, n=2):
    s = 1
    while n > 0:
        s = s * x
        n = n - 1
    return s
print(power(5))
print(power(5, 3))

# %% [markdown]
# 可变参数：

# %%
def calc(*numbers): # *numbers表示参数numbers接收的是一个tuple
    sum = 0
    for n in numbers:
        sum = sum + n * n
    return sum
print(calc(1, 2, 3))

# %% [markdown]
# 如果已经有一个 list/tuple

# %%
nums = [1, 2, 3]
print(calc(nums[0], nums[1], nums[2]))
print(calc(*nums)) # *nums表示把nums这个list的所有元素作为可变参数传进去

# %% [markdown]
# 关键字参数：
#
# 关键字参数允许你传入0个或任意个含参数名的参数，这些关键字参数在函数内部自动组装为一个dict

# %%
def person(name, age, **kw): # **kw表示关键字参数，它接收的是一个dict
    print('name:', name, 'age:', age, 'other:', kw)
person('Michael', 30)
person('Bob', 35, city='Beijing', job='Engineer')
extra = {'city': 'Beijing', 'job': 'Engineer'}
person('Jack', 24, **extra) # **extra表示把extra这个dict的所有key-value用关键字参数传入到函数的**kw参数中

# %% [markdown]
# 命名关键字参数：

# %%
def person1(name, age, *, city, job): # *表示命名关键字参数，必须传入参数名
    print(name, age, city, job)
person1('Jack', 24, city='Beijing', job='Engineer')

# %%
def person2(name, age, *, city='Beijing', job): # 命名关键字参数可以有默认值
    print(name, age, city, job) 
person2('Jack', 24, job='Engineer')

# %%
def person3(name, age, *arg, city, job): # 命名关键字参数可以和可变参数一起使用
    print(name, age, arg, city, job)
person3('Jack', 24, 'A', 'B', city='Beijing', job='Engineer')

# %% [markdown]
# ## 3.4 递归函数

# %%
def fact(n):
    if n == 1:
        return 1
    return n * fact(n - 1)
print(fact(5))

# %% [markdown]
# 为了防止栈溢出，采用尾递归（在函数返回的时候，调用自身本身，并且return语句不能包含表达式）

# %%
def fact(n):
    return fact_iter(n, 1)

def fact_iter(num, product):
    if num == 1:
        return product
    return fact_iter(num - 1, num * product)
print(fact(5))
