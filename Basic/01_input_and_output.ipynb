# %% [markdown]
# # 1 第一个Python程序

# %% [markdown]
# 输出，可用逗号隔开，输出多个值

# %%
print('hello,world')
print('hello,world','moon')
print('200+300=',200+300)

# %% [markdown]
# 输入

# %%
name = input('请输入你的名字：')
print('你好，',name)
