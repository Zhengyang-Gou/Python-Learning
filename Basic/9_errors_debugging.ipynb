# %% [markdown]
# # 9 错误、调试与测试

# %% [markdown]
# ## 9.1 错误处理

# %% [markdown]
# 程序运行的过程中，如果发生了错误，可以事先约定返回一个错误代码，这样，就可以知道是否有错，以及出错的原因

# %%
try:
    print('try...')
    r = 10 / int('2')
    print('result:', r)
except ValueError as e:
    print('ValueError:', e)
except ZeroDivisionError as e:
    print('ZeroDivisionError:', e)
else:
    print('no error!')
finally:
    print('finally...')
print('END')
# Out:
# try...
# result: 5.0
# no error!
# finally...
# END

# %% [markdown]
# 使用try...except捕获错误的好处是可以跨越多层调用

# %%
def foo(s):
    return 10 / int(s)

def bar(s):
    return foo(s) * 2

def main():
    try:
        bar('0')
    except Exception as e:
        print('Error:', e)
    finally:
        print('finally...')

main()
# Out:
# Error: division by zero
# finally...

# %% [markdown]
# 调用栈：
#
# 如果错误没有被捕获，它就会一直往上抛，最后被Python解释器捕获，打印一个错误信息，然后程序退出

# %%
# err.py:
def foo(s):
    return 10 / int(s)

def bar(s):
    return foo(s) * 2

def main():
    bar('0')

main()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 11
#       8 def main():
#       9     bar('0')
# ---> 11 main()
#
# Cell In[3], line 9, in main()
#       8 def main():
# ----> 9     bar('0')
#
# Cell In[3], line 6, in bar(s)
#       5 def bar(s):
# ----> 6     return foo(s) * 2
#
# Cell In[3], line 3, in foo(s)
#       2 def foo(s):
# ----> 3     return 10 / int(s)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 记录错误：

# %%
import logging

def foo(s):
    return 10 / int(s)

def bar(s):
    return foo(s) * 2

def main():
    try:
        bar('0')
    except Exception as e:
        logging.exception(e)

main()
print('END')
# Out:
# ERROR:root:division by zero
# Traceback (most recent call last):
#   File "C:\Users\33199\AppData\Local\Temp\ipykernel_25380\1371240815.py", line 11, in main
#     bar('0')
#   File "C:\Users\33199\AppData\Local\Temp\ipykernel_25380\1371240815.py", line 7, in bar
#     return foo(s) * 2
#            ^^^^^^
#   File "C:\Users\33199\AppData\Local\Temp\ipykernel_25380\1371240815.py", line 4, in foo
#     return 10 / int(s)
#            ~~~^~~~~~~~
# ZeroDivisionError: division by zero
# END

# %% [markdown]
# 抛出错误：

# %%
class FooError(ValueError):
    pass

def foo(s):
    n = int(s)
    if n==0:
        raise FooError('invalid value: %s' % s)
    return 10 / n

foo('0')
# Out:
# ---------------------------------------------------------------------------
# FooError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       7         raise FooError('invalid value: %s' % s)
#       8     return 10 / n
# ---> 10 foo('0')
#
# Cell In[5], line 7, in foo(s)
#       5 n = int(s)
#       6 if n==0:
# ----> 7     raise FooError('invalid value: %s' % s)
#       8 return 10 / n
#
# FooError: invalid value: 0

# %% [markdown]
# ## 9.2 调试

# %% [markdown]
# 第一种方法，用 print 打印可能有问题的变量

# %%
def foo(s):
    n = int(s)
    print('>>> n = %d' % n)
    return 10 / n

def main():
    foo('0')

main()
# Out:
# >>> n = 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 9
#       6 def main():
#       7     foo('0')
# ----> 9 main()
#
# Cell In[6], line 7, in main()
#       6 def main():
# ----> 7     foo('0')
#
# Cell In[6], line 4, in foo(s)
#       2 n = int(s)
#       3 print('>>> n = %d' % n)
# ----> 4 return 10 / n
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 第二种方法，使用 assert

# %%
def foo(s):
    n = int(s)
    assert n != 0, 'n is zero!'
    return 10 / n

def main():
    foo('0')

main()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 9
#       6 def main():
#       7     foo('0')
# ----> 9 main()
#
# Cell In[7], line 7, in main()
#       6 def main():
# ----> 7     foo('0')
#
# Cell In[7], line 3, in foo(s)
#       1 def foo(s):
#       2     n = int(s)
# ----> 3     assert n != 0, 'n is zero!'
#       4     return 10 / n
#
# AssertionError: n is zero!

# %% [markdown]
# 第三种方法，使用 logging

# %%
import logging

s = '0'
n = int(s)
logging.info('n = %d' % n)
print(10 / n)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 6
#       4 n = int(s)
#       5 logging.info('n = %d' % n)
# ----> 6 print(10 / n)
#
# ZeroDivisionError: division by zero

# %%
import logging
logging.basicConfig(level=logging.INFO)

s = '0'
n = int(s)
logging.info('n = %d' % n)
print(10 / n)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 n = int(s)
#       6 logging.info('n = %d' % n)
# ----> 7 print(10 / n)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 使用 pdb，在可能出错的地方放一个pdb.set_trace()

# %%
# err.py
import pdb

s = '0'
n = int(s)
pdb.set_trace() # 运行到这里会自动暂停
print(10 / n)
# Out:
# --Return--
# None
# > c:\users\33199\appdata\local\temp\ipykernel_25380\2506498340.py(6)<module>()
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 7
#       5 n = int(s)
#       6 pdb.set_trace() # 运行到这里会自动暂停
# ----> 7 print(10 / n)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ##
